# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\HP\Downloads\laptop_details.csv")

# %%
data
# Out:
#                                                Product  Rating        MRP  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...     4.2    ₹36,990
# 1    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.2    ₹39,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3    ₹32,990
# 3    HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...     4.4    ₹49,990
# 4    ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.4    ₹49,990
# ..                                                 ...     ...        ...
# 715  ASUS Chromebook Flip Touch Celeron Dual Core -...     4.0    ₹23,490
# 716  Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD ...     4.5    ₹73,490
# 717  ASUS ROG Zephyrus G15 Ryzen 9 Octa Core 6900HS...     NaN  ₹1,94,990
# 718  ASUS Zenbook Flip 14 OLED (2022) Touch Panel C...     3.0  ₹1,25,990
# 719  Lenovo Ideapad Slim 3i Core i5 10th Gen - (8 G...     4.2    ₹50,990
#
#                                                Feature
# ...

# %% [raw]
# brand = []
# for i in len(data):
#     if "Core" in data['Product'][i]:
#         brand.append(data['Product'][i].split(" Core")[0])
#     else:
#         brand.append(data['Product'][i].split(" -")[0])
# data[['brand']] = pd.DataFrame(brand)

# %%
a = []
for i in data['Product']:
    if "Core" in i:
        a.append(i.split(' Core')[0])
    else:
        a.append(i.split(' -'))
data['brand'] = pd.DataFrame(a)

# %%
for i in range(len(data)):
    print(i)
    print(data['Processor'][i])
# Out:
# 0
# Intel Core i3
# 1
# Intel Core i3
# 2
# Intel Core i3
# 3
# AMD Ryzen 5 Hexa Core
# 4
# Intel Core i5
# 5
# Intel Core i3
# 6
# Intel Core i5
# 7
# AMD Ryzen 7 Quad Core
# 8
# AMD Ryzen 5 Hexa Core
# 9
# AMD Ryzen 5 Quad Core
# 10
# Intel Core i3
# 11
# AMD Ryzen 5 Hexa Core
# 12
# Intel Core i3
# 13
# AMD Ryzen 9 Octa Core
# 14
# Intel Core i5
# 15
# Intel Core i5
# 16
# AMD Ryzen 5 Hexa Core
# 17
# AMD Ryzen 7 Octa Core
# 18
# Apple M1
# 19
# Intel Core i3
# 20
# Intel Celeron Dual Core
# 21
# AMD Ryzen 3 Dual Core
# 22
# Intel Core i5
# 23
# Intel Core i5
# 24
# Intel Core i3
# 25
# AMD Ryzen 9 Octa Core
# 26
# Intel Core i5
# 27
# AMD Ryzen 5 Quad Core
# 28
# AMD Ryzen 7 Octa Core
# 29
# AMD Ryzen 3 Dual Core
# 30
# AMD Ryzen 7 Octa Core
# 31
# Intel Core i5
# 32
# AMD Ryzen 3 Dual Core
# 33
# AMD Ryzen 9 Octa Core
# 34
# Intel Core i5
# 35
# Intel Core i5
# 36
# Intel Core i3
# 37
# AMD Ryzen 9 Octa Core
# 38
# AMD Ryzen 5 Hexa Core
# 39
# AMD Athlon Dual Core
# 40
# ...

# %%
data.loc[[689]]
# Out:
#                                                Product  Rating        MRP  \
# 689  ALIENWARE Core i7 10th Gen - (16 GB/512 GB SSD...     4.9  ₹1,99,990
#
#                                                Feature      brand Processor
# 689  NVIDIA GeForce GTX 1660 Ti15.6 inch Full HD LE...  ALIENWARE       NaN

# %%
Processor = [ ]
for i in range(len(df)):
    if  df['Feature'][i].startswith('Intel') or df['Feature'][i].startswith('AMD') or df['Feature'][i].startswith('Apple'):
        Processor.append(df['Feature'][i].split(' Processor')[0])
    else:
        Processor.append(re.findall(r'(Core [i]\d | Ryzen \d | Snapdragon \d\w | Pentium)' ,df.iloc[i]['Product'])[0].strip())
for i in range(720):
    if Processor[i].startswith('Core'):
        Processor[i] = 'Intel '+Processor[i]
    elif Processor[i].startswith('Ry'):
        Processor[i] = 'AMD '+Processor[i]
df[['Processor']] = pd.DataFrame(Processor)
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...     4.2  ₹36,990
# 1  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.2  ₹39,990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3  ₹32,990
# 3  HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...     4.4  ₹49,990
# 4  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.4  ₹49,990
#
#                                              Feature                     brand
# 0  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...          Lenovo IdeaPad 3
# 1  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...          Lenovo IdeaPad 3
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...   ASUS VivoBook 15 (2022)
# 3  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...  HP Pavilion Ryzen 5 Hexa
# 4  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...       ASUS TUF Gaming F15

# %%
Processor = []
for i in data['Feature']:
    if i.startswith("Intel") or i.startswith("AMD") or i.startswith("Apple"):
        Processor.append(i.split("Processor")[0])
data['Processor'] = pd.DataFrame(Processor)

# %%
data
# Out:
#                                                Product  Rating        MRP  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...     4.2    ₹36,990
# 1    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.2    ₹39,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3    ₹32,990
# 3    HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...     4.4    ₹49,990
# 4    ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.4    ₹49,990
# ..                                                 ...     ...        ...
# 715  ASUS Chromebook Flip Touch Celeron Dual Core -...     4.0    ₹23,490
# 716  Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD ...     4.5    ₹73,490
# 717  ASUS ROG Zephyrus G15 Ryzen 9 Octa Core 6900HS...     NaN  ₹1,94,990
# 718  ASUS Zenbook Flip 14 OLED (2022) Touch Panel C...     3.0  ₹1,25,990
# 719  Lenovo Ideapad Slim 3i Core i5 10th Gen - (8 G...     4.2    ₹50,990
#
#                                                Feature  \
# ...
